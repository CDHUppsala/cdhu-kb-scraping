# %% [markdown]
# # Extract government SOU dataset at https://sou.kb.se (Kungliga biblioteket)
#
# This notebook extracts all pdf-links from https://sou.kb.se. The links are written to "sou_pdf_links.txt" and, as a batch of wget commands with proper output anmes (filesystem sane), to "wget_all.sh". Edit the wget_all.sh to limit downloads to a smaller range of years if needed – the dataset is relatively huge (hundreds of gigabytes). Use chmod +x and then execute in a Linux/Unix environment.
#
# ```python
# CDHU="""\
#  ____ ____ ____ ____ ________
# ||C |||D |||H |||U |||
# ||__|||__|||__|||__|||_______
# |/__\|/__\|/__\|/__\|/_______
#
#  EXTRACT SOU / BEAUTIFUL SOUP
# """
# ```

# %%
# Code: Matts L/CDHU
# Reuires: urllib, BeautifulSoup4, pandas
from urllib import request
from bs4 import BeautifulSoup
import re
import pandas as pd 

# connect to website and get list of all pdfs
url="https://sou.kb.se"
response = request.urlopen(url).read()
soup= BeautifulSoup(response, "html.parser")     
links = soup.find_all('a', href=re.compile(r'(sou-\d)'))

# %%
TESTING=False
sou_urn_links = []
sou_names = []
sou_pdf_links = []

#Gets all A tags with SOU:s
a_tags = soup.find_all('a', href=re.compile(r'(sou-\d)'))

count=0
limit=1500 #limit requests when testing

#Iterates all A tags
for l in a_tags:
    count=count+1
    if count >= limit and TESTING:
      print("testing, limit="+str(limit))
      break
    # Get and store SOU name and urn sub page link
    sou_page = l.get('href')
    sou_urn_links.append(sou_page)
    sou_link_text = l.get_text()
    sou_names.append(sou_link_text)
    # Request urn page and extract PDF link
    print(  '++ Requesting URN-sub page (' \
             +sou_link_text+ \
             ') and extracting pdf-link... ', 
             end = '')
    response = request.urlopen(sou_page).read()
    soup2=BeautifulSoup(response, "html.parser")
    for l in soup2.find_all('a', href=re.compile(r'(\.pdf)')):
      pdf_link = l.get('href')
      sou_pdf_links.append(pdf_link)
    print('Done.')
# Out:
# ++ Requesting URN-sub page (1922:1 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:2 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:3 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:4 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:5 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:6 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:7 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:8 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:9 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:10 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:11 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:12 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:13 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:14 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:15 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:16 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:17 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:18 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:19 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:20 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:21 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:22 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:23 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:24 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:25 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:26 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:27 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:28 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:29 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:30 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:31 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:32 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:33 B första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:33 A första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:34 första serien) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:41) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:42) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:43) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:44) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:45) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:46) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:47) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:48) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:49) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:50) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:51) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:52) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:53) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:54) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:55) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:56) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:57) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:58) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1922:59) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:41) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:42) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:43) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:44) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:45) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:46) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:47) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:48) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:49) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:50) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:51) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:52) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:53) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:54) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:55) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:56) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:57) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:58) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:59) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:60) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:61) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:62) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:63) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:64) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:65) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:66) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:67) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:68) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:69) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:70) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:71) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:72) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:73) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:74) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:75) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:76) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:77) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1923:78) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:41) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:42) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:43) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:44) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:45) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:46) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:47) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:48) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:49) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:50) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:51) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:52) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:53) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:54) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:55) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:56) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:57) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:58) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:59) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1924:60) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:41) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:42) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:43) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:44) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1925:45) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1926:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1927:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1928:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1929:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1930:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:41) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1931:42) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1932:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1933:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:41) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:42) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:43) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:44) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:45) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:46) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:47) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:48) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:49) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:50) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:51) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:52) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:53) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:54) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:55) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1934:56) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:41) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:42) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:43) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:44) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:45) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:46) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:47) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:48) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:49) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1935:50) and extracting pdf-link... Done.
# ...
# ++ Requesting URN-sub page (1998:108) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:109) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:110) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:111) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:112) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:113) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:114) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:115) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:116) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:118) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:118) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:119) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:120) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:121) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:122) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:123) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:124) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:125) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:126) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:127) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:128) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:129) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:130) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:131) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:132) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:133) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:134) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:135) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:136) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:137) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:138) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:139) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:140) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:141) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:141) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:142) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:143) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:144) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:145) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:146) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:147) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:148) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:149) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:150) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:151) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:151) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:152) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:153) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:154) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:155) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:156) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:157) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:158) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:159) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:160) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:161) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:162) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:163) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:164) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:165) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:166) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:168) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:169) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1998:170) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:1) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:2) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:3) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:4) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:5) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:6) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:7) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:8) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:9) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:10) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:11) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:12) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:13) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:14) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:15) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:16) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:17) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:18) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:19) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:20) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:21) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:22) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:23) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:24) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:25) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:26) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:27) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:28) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:29) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:30) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:31) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:32) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:33) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:34) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:35) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:36) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:37) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:38) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:39) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:40) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:41) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:42) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:43) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:44) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:45) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:46) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:47) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:48) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:49) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:50) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:51) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:51) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:52) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:53) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:54) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:55) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:56) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:57) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:58) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:59) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:60) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:61) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:62) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:63) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:64) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:65) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:66) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:66) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:66) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:67) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:68) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:69) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:70) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:71) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:72) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:73) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:74) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:75) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:75) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:76) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:77) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:78) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:79) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:80) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:81) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:82) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:84) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:85) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:86) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:87) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:88) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:89) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:90) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:91) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:92) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:93) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:94) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:95) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:96) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:96) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:97) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:97) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:98) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:99) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:100) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:100) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:100) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:100) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:101) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:102) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:103) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:104) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:105) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:106) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:107) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:108) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:109) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:110) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:111) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:112) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:113) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:114) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:115) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:116) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:117) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:118) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:119) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:120) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:121) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:122) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:123) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:124) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:125) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:126) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:127) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:128) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:129) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:130) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:131) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:132) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:133) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:134) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:135) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:136) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:137) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:138) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:139) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:140) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:141) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:142) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:143) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:144) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:145) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:146) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:146) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:147) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:148) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:149) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:150) and extracting pdf-link... Done.
# ++ Requesting URN-sub page (1999:151) and extracting pdf-link... Done.

# %%
DECADE=1920 #set starting decade

#package with pandas:
dict = {'titel': sou_names, 'pdf': sou_pdf_links, 'urn': sou_urn_links}
df = pd.DataFrame(dict)

#//UNUSED:
#code here to packager everything in a table with zip()
#sou_table = list(zip(sou_names, sou_pdf_links, sou_urn_links))
#print(sou_table)
#print(sou_pdf_links)

# write to file
# and/or output as string
sous_csv_string = df.to_csv()
try:
  df.to_csv('sous.csv')
except: 
  print('-- Error!')
else:
  print('++ Wrote sous.csv')
try:
  with open(r'wget_all.sh', 'w') as fp:
    fp.write("#!/bin/bash\n")
    for ind in df.index:
          df_titel = df['titel'][ind]
          result = re.search(r'(\d\d\d\d)(\:)', df_titel)
          year=(result.group(1))
          if int(year)-DECADE == 10:
            DECADE=DECADE+10 # inc 10 yrs
            fp.write("# "+str(DECADE)+"\n")

          url = df['pdf'][ind]
          out_file = df['titel'][ind]
          #sanitize
          #out_file = "".join([c for c in out_file if c.isalpha() or c.isdigit() or c==' ']).rstrip()
          #TODO: should use more regex and zfill() for better, corretcly sortable, filename numbers here...
          out_file = out_file.replace(" ", "_")
          out_file = out_file.replace(":", "-")
          out_file = out_file.replace("/", "-")
          out_file = 'sou-'+out_file
          command = 'wget --continue -O \"'+out_file+'.pdf\" '+url
          #write each item on a new line
          fp.write("%s\n" % command)
except:
  print("-- Error!")
else:
  print('++ Wrote wget_all.sh')

# Write pdf links for wget
# (To parallelize dl, you can use something like: cat sou_pdf_links.txt | parallel --gnu "wget {}"
# ...to download parallelised)
# Useful => metadata in SOU-pdfs: pdfinfo -enc UTF-8 <filename.pdf> gets full swedish titles and libris ID.
try:
  with open(r'sou_pdf_links.txt', 'w') as fp:
      for item in sou_pdf_links:
          # write each item on a new line
          fp.write("%s\n" % item)
except:
  print("-- Error!")
else:
  print('++ Wrote sou_pdf_links.txt')
# Out:
# ++ Wrote sous.csv
# ++ Wrote wget_all.sh
# ++ Wrote sou_pdf_links.txt
